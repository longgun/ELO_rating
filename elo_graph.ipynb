# %%
from elo_rating import ELOMaker
import matplotlib.pyplot as plt
import random

# %%
OBJ = ELOMaker()

# %%
df = OBJ.read_nba_data("./nba_schedule_and_results")

# %%
import pandas as pd

# %%
plt.figure(figsize=(15, 15))
for team, scores in df.teams_elo.items():
    # print(team)
    # print(scores)
    # if team[:2].lower() in ["me", "go", "br", "lo", "ph", "ut", "cl"]:
    plt.plot(scores)
    plt.text(len(scores) - 1, scores[-1] + random.uniform(-1, 1) * 10, team)
